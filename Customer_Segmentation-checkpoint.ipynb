# %%
# Customer Segmentation Analysis

## Objective

Analyze customer data and segment customers into groups using the K-Means Clustering algorithm.

Author: Mehak Chauhan

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
## Load Dataset

# %%
df = pd.read_csv("customer_segmentation.csv")

df.head()
# Out:
#   Customer ID  Age  Gender  Annual_Income  Spending_Score
# 0        C001   19  Female          15000              39
# 1        C002   21    Male          16000              81
# 2        C003   20  Female          17000               6
# 3        C004   23    Male          18000              77
# 4        C005   31  Female          19000              40

# %%
## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     50 non-null     object
#  1   Age             50 non-null     int64
#  2   Gender          50 non-null     object
#  3   Annual_Income   50 non-null     int64
#  4   Spending_Score  50 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#              Age  Annual_Income  Spending_Score
# count  50.000000      50.000000        50.00000
# mean   35.960000   39500.000000        49.80000
# std    13.871068   14577.379737        32.52001
# min    18.000000   15000.000000         3.00000
# 25%    23.250000   27250.000000        17.25000
# 50%    34.000000   39500.000000        50.50000
# 75%    46.750000   51750.000000        78.50000
# max    67.000000   64000.000000        99.00000

# %%
df.isnull().sum()
# Out:
# Customer ID       0
# Age               0
# Gender            0
# Annual_Income     0
# Spending_Score    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
## Exploratory Data Analysis

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Annual_Income"], bins=20)
plt.title("Annual Income Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Spending_Score"], bins=20)
plt.title("Spending Score Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="Annual_Income",
    y="Spending_Score",
    data=df
)
plt.show()

# %%
## Feature Selection

# %%
X = df[["Annual_Income", "Spending_Score"]]

# %%
## Scaling Features

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
## Elbow Method

# %%
import warnings
warnings.filterwarnings("ignore")
wcss = []

for i in range(1,11):
    model = KMeans(n_clusters=i, random_state=42)
    model.fit(X_scaled)
    wcss.append(model.inertia_)

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
## K-Means Clustering

# %%
kmeans = KMeans(n_clusters=5, random_state=42)

clusters = kmeans.fit_predict(X_scaled)

# %%
df["Cluster"] = clusters

# %%
## Customer Segments

# %%
plt.figure(figsize=(10,7))

sns.scatterplot(
    x="Annual_Income",
    y="Spending_Score",
    hue="Cluster",
    palette="Set1",
    data=df,
    s=100)

plt.title("Customer Segments")
plt.show()

# %% [markdown]
# ## Business Insights
#
# - Cluster 0: Premium Customers
# - Cluster 1: Budget Customers
# - Cluster 2: Potential Customers
# - Cluster 3: Regular Customers
# - Cluster 4: High-Spending Customers
#
# These insights can help businesses design targeted marketing campaigns.
